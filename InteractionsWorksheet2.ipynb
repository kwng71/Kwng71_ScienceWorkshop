# %% [markdown]
# # <span style="color:red">Primary </span> <span style="color:orange"> School </span> <span style="color:yellow"> Science </span> <span style="color:green"> Worksheet </span> <span style="color:blue"> Rainbow </span> <span style="color:indigo"> Series </span><span style="color:purple">(Experiments) </span>
# ## <span style="color:blue">Theme: Interactions </span>
# ## <span style="color:blue">Topic: Factors that Affect Growth of Bacteria  </span>
# ### Let's watch a short video clip on growing bacteria.

# %%
# Click the 'Run' button to activate the video clip..
#https://www.youtube.com/watch?v=A0b6_kg2oMc
from IPython.lib.display import YouTubeVideo
YouTubeVideo('A0b6_kg2oMc')

# %% [markdown]
# ### Experiment Detail:
# ### A group of students carried out an experiment to find out the effectiveness of different types of herbs in soap against bacteria. They put an equal amount of soap in 4 petri-dishes and measured the area in which bacteria grew.
#
# ### The diagram below shows how the experiment could be set up.

# %%
# Experiment Setup:
from IPython.display import display
from IPython.display import clear_output
from IPython.display import Image
import time
clear_output(wait=True)
display(Image(url='DiagramQ18_1.jpg'))
# Out:
# <img src="DiagramQ18_1.jpg"/>

# %% [markdown]
# ### The results were recorded and shown below.
#
# | Set-up | Area of bacterial growth(cm2)|
# | :-------------| -----------------------------------------------: |
# | Soap Only | 15.0 |
# | Soap + Herb A| 9.2 |
# | Soap + Herb B| 12.5 |
# | Soap + Herb C| 2.1

# %% [markdown]
# ### Questions 1:
# ### How do bacteria multiply?

# %% [markdown]
# Type your answer:

# %%
#Hint: Watch the short video clip below if you are stuck..
#https://www.youtube.com/watch?v=gEwzDydciWc
from IPython.lib.display import YouTubeVideo
YouTubeVideo('gEwzDydciWc')

# %% [markdown]
# ### Question 2:
# ### What is the purpose of the setup that contains only soap?

# %% [markdown]
# Type your answer:

# %%
# Watch the video clip below if you are stuck..
#https://www.youtube.com/watch?v=0A55QRyJHPM
from IPython.lib.display import YouTubeVideo
YouTubeVideo('0A55QRyJHPM')

# %% [markdown]
# ### Questions 3:
# ### Which herb would you recommend being used in the homemade soap? Explain your answer.

# %% [markdown]
# Type your answer:

# %%
# If you are stuck, find out which dependant variable is the lowest in the result table..

# %% [markdown]
# ### Question 4(Challenging):
# ### Suggest another way to estimate the bacterial growth by drawing it out.
# ### Highlight the cell below and click 'Run' button to capture your drawing with the webcam

# %%
# Webcam:
# Code developed by Dirk Colbry
# This code snipit tries to read from your computer's camera.  It is not fully tested so it may not work for everyone.

from IPython.display import HTML

main_text = """
<video id="video" width="320" height="240" autoplay></video>
<button id="snap">Snap Photo</button>
<canvas id="canvas" width="320" height="240"></canvas>

<script>
// Grab elements, create settings, etc.
var video = document.getElementById('video');

// Get access to the camera!
if(navigator.mediaDevices && navigator.mediaDevices.getUserMedia) {
    // Not adding `{ audio: true }` since we only want video now
    navigator.mediaDevices.getUserMedia({ video: true }).then(function(stream) {
        //video.src = window.URL.createObjectURL(stream);
        //video.play();
        video.srcObject=stream;
        video.play();
    });
}

// Elements for taking the snapshot
var canvas = document.getElementById('canvas');
var context = canvas.getContext('2d');
var video = document.getElementById('video');

// Trigger photo take
document.getElementById("snap").addEventListener("click", function() {
	context.drawImage(video, 0, 0, 320, 240);
    var myCanvas = document.getElementById('canvas');
    var image = myCanvas.toDataURL("image/png");
    IPython.notebook.kernel.execute("print('testing')")
    IPython.notebook.kernel.execute("image = '" + image + "'")
});
</script>

"""
HTML(main_text)
# Out:
# <video id="video" width="320" height="240" autoplay></video>
# <button id="snap">Snap Photo</button>
# <canvas id="canvas" width="320" height="240"></canvas>
#
# <script>
# // Grab elements, create settings, etc.
# var video = document.getElementById('video');
#
# // Get access to the camera!
# if(navigator.mediaDevices && navigator.mediaDevices.getUserMedia) {
#     // Not adding `{ audio: true }` since we only want video now
#     navigator.mediaDevices.getUserMedia({ video: true }).then(function(stream) {
#         //video.src = window.URL.createObjectURL(stream);
#         //video.play();
#         video.srcObject=stream;
#         video.play();
#     });
# }
#
# // Elements for taking the snapshot
# var canvas = document.getElementById('canvas');
# var context = canvas.getContext('2d');
# var video = document.getElementById('video');
#
# // Trigger photo take
# document.getElementById("snap").addEventListener("click", function() {
# 	context.drawImage(video, 0, 0, 320, 240);
# ...

# %%
# Click the 'Run' button for some hints if you are stuck
from IPython.display import display
from IPython.display import clear_output
from IPython.display import Image
import time
clear_output(wait=True)
display(Image(url='AnswerKeyQ18_d.jpg'))
time.sleep(10)
clear_output(wait=True)
display(Image(url='BlankPage.jpg'))
# Out:
# <img src="BlankPage.jpg"/>

# %% [markdown]
# ### Main Learning Points:
# ### 1) Ensure you use the following key words when you answer the questions:
# #### -cell dvision
# #### -control set-up
# #### -bacterial growth
# #### -colonies
# ### 2) Bacteria carry out cell division to multiply.
# ### 3) The control set-up aims to cancel out the influences of other variables on the experiment outcomes.
# ### 4) In this way, the bacterial growth rate is only dependant on the type of herb.
# ### 5) The bacteria growth rate can be indicated by the area of the bacteria or number of colonies on soap.
# ### 6) The bacteria growth rate is the Dependant Variable.
# ### 7) The type of soap is the Independant Variable.

# %% [markdown]
# # <span style="color:red">Thumbs </span> <span style="color:orange"> Up </span> <span style="color:yellow"> for </span> <span style="color:green"> completing </span> <span style="color:blue"> this </span> <span style="color:indigo"> worksheet </span><span style="color:purple"> !!! </span>

# %%
# You deserve some fireworks your GREAT efforts... 
from IPython.display import HTML

HTML("""
<div align="middle">
<video width="50%" controls>
      <source src="Fireworks.mp4" type="video/mp4">
</video></div>""")

# %% [markdown]
# ### <span style="color:red">Let's </span> <span style="color:orange"> have </span> <span style="color:yellow"> fun </span> <span style="color:green"> learning </span> <span style="color:blue"> some </span> <span style="color:indigo"> coding </span><span style="color:purple"> techniques.... </span>

# %%
# Have Fun with Python Programming: To play a piece of music..

# Insert the url of the sound file below and click run to play your music.

from IPython.display import Audio
Audio(url='https://file-examples.com/wp-content/uploads/2017/11/file_example_WAV_1MG.wav',autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="https://file-examples.com/wp-content/uploads/2017/11/file_example_WAV_1MG.wav" type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Tutor's Feedback:
